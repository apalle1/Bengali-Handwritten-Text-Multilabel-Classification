# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/BengaliAI/src'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/BengaliAI/src

# %%
#Uncomment the below line to create pickle files
#!python ./src/create_image_pickles.py

# %%
# !pip install pretrainedmodels
# Out:
# ...
#      |████████████████████████████████| 61kB 4.5MB/s
# ...
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-cp36-none-any.whl size=60962 sha256=3a34af83406c376a2f6b76bc31ba2337bf7632d0d2dbaf32a84fd07970b127d7
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
# Successfully built pretrainedmodels
# ...

# %%
# !python ./train.py
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100% 83.3M/83.3M [00:00<00:00, 90.2MB/s]
# Traceback (most recent call last):
#   File "./train.py", line 299, in <module>
#     main()
#   File "./train.py", line 227, in main
#     print(train_dataset[0])
#   File "/content/drive/My Drive/BengaliAI/src/dataset.py", line 46, in __getitem__
#     image = joblib.load(f"../input/image_pickles/{self.image_ids[item]}.pkl")
#   File "/usr/local/lib/python3.6/dist-packages/joblib/numpy_pickle.py", line 577, in load
#     with open(filename, 'rb') as f:
# OSError: [Errno 5] Input/output error: '../input/image_pickles/Train_176219.pkl'
